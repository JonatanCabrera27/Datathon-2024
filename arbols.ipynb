# %%
import pandas as pd

# %%
df = pd.read_csv('./data2/arboles.csv')

# %%
df.sample(10)
# Out:
#       id_arbol                                  direccion       tipo_vereda  \
# 6098      6054                       C171 y av. Patagonia             Chica
# 3075      3557                         La pampa c.7  1230             Chica
# 3132      3627                   Lavalle esq. Blas parera             Chica
# 2568      2900                            pago largo 1247           Mediana
# 5956      5147                               Parque mitre             Plaza
# 6648      6697                                E. Chamorro  Parterre Central
# 625        758                             Don Bosco 1171            Grande
# 5459      6418     Av. Costanera Juan Pablo II y Lamadrid             Chica
# 5246      6198                              Pio XXII 2050           Mediana
# 2907      3327  Av Costanera Sur Juan Pablo II y Gral Paz            Grande
#
#      lado_vereda           especie                    tipo_tendido  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7141 entries, 0 to 7140
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_arbol            7141 non-null   int64
#  1   direccion           7141 non-null   object
#  2   tipo_vereda         7141 non-null   object
#  3   lado_vereda         7141 non-null   object
#  4   especie             7141 non-null   object
#  5   tipo_tendido        7141 non-null   object
#  6   distancia_entre_ar  7141 non-null   float64
#  7   distancia_al_muro   7141 non-null   float64
#  8   activo              7141 non-null   bool
#  9   lng                 7141 non-null   object
#  10  lat                 7141 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 565.0+ KB

# %%
df.isnull().sum()
# Out:
# id_arbol              0
# direccion             0
# tipo_vereda           0
# lado_vereda           0
# especie               0
# tipo_tendido          0
# distancia_entre_ar    0
# distancia_al_muro     0
# activo                0
# lng                   0
# lat                   0
# dtype: int64

# %%
top_especies = df['especie'].value_counts()
print(top_especies)
# Out:
# especie
# Fresno                 1159
# Palmera                 900
# Lapacho rosado          756
# Pata de Buey            454
# Naranjo agrio           273
#                        ...
# Cordia Americana          1
# Eucalipto                 1
# Mora de Papel             1
# Catalpa bigninoides       1
# Mirto                     1
# Name: count, Length: 81, dtype: int64
